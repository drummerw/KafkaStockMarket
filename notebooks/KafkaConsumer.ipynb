# %%
pip install s3fs

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo',
     bootstrap_servers=['15.240.164.146:9092'],
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for message in consumer:
    print(message.value)
# Out:
# {'Index': 'NYA', 'Date': '1983-04-21', 'Open': 972.25, 'High': 972.25, 'Low': 972.25, 'Close': 972.25, 'Adj Close': 972.25, 'Volume': 0.0, 'CloseUSD': 972.25}
# {'Index': 'N225', 'Date': '1968-09-04', 'Open': 1705.150024, 'High': 1705.150024, 'Low': 1705.150024, 'Close': 1705.150024, 'Adj Close': 1705.150024, 'Volume': 0.0, 'CloseUSD': 17.05150024}
# {'Index': 'NSEI', 'Date': '2016-09-08', 'Open': 8915.5, 'High': 8960.349609, 'Low': 8896.0, 'Close': 8952.5, 'Adj Close': 8952.5, 'Volume': 217200.0, 'CloseUSD': 89.525}
# {'Index': 'IXIC', 'Date': '1995-01-25', 'Open': 759.690002, 'High': 763.340027, 'Low': 757.190002, 'Close': 760.97998, 'Adj Close': 760.97998, 'Volume': 313100000.0, 'CloseUSD': 760.97998}
# {'Index': 'IXIC', 'Date': '2010-04-13', 'Open': 2454.949951, 'High': 2467.939941, 'Low': 2445.26001, 'Close': 2465.98999, 'Adj Close': 2465.98999, 'Volume': 2665420000.0, 'CloseUSD': 2465.98999}
# {'Index': 'GDAXI', 'Date': '2010-06-17', 'Open': 6181.77002, 'High': 6241.359863, 'Low': 6164.990234, 'Close': 6223.540039, 'Adj Close': 6223.540039, 'Volume': 112716300.0, 'CloseUSD': 7592.71884758}
# {'Index': 'GDAXI', 'Date': '1994-08-22', 'Open': 2141.159912, 'High': 2146.409912, 'Low': 2108.959961, 'Close': 2113.370117, 'Adj Close': 2113.370117, 'Volume': 0.0, 'CloseUSD': 2578.31154274}
# {'Index': 'TWII', 'Date': '2013-06-13', 'Open': 8041.5, 'High': 8057.330078, 'Low': 7951.660156, 'Close': 7951.660156, 'Adj Close': 7951.629883, 'Volume': 2286800.0, 'CloseUSD': 318.06640624}
# {'Index': 'IXIC', 'Date': '1982-08-19', 'Open': 164.919998, 'High': 164.919998, 'Low': 164.919998, 'Close': 164.919998, 'Adj Close': 164.919998, 'Volume': 0.0, 'CloseUSD': 164.919998}
# {'Index': 'N100', 'Date': '2000-02-29', 'Open': 1007.320007, 'High': 1007.320007, 'Low': 1007.320007, 'Close': 1007.320007, 'Adj Close': 1007.320007, 'Volume': 0.0, 'CloseUSD': 1228.93040854}
# {'Index': 'SSMI', 'Date': '2003-05-20', 'Open': 4475.100098, 'High': 4522.100098, 'Low': 4432.299805, 'Close': 4514.399902, 'Adj Close': 4514.399902, 'Volume': 57228400.0, 'CloseUSD': 5010.98389122}
# {'Index': 'NYA', 'Date': '1993-01-06', 'Open': 2528.709961, 'High': 2528.709961, 'Low': 2528.709961, 'Close': 2528.709961, 'Adj Close': 2528.709961, 'Volume': 0.0, 'CloseUSD': 2528.709961}
# {'Index': 'N225', 'Date': '1979-10-01', 'Open': 6577.890137, 'High': 6577.890137, 'Low': 6577.890137, 'Close': 6577.890137, 'Adj Close': 6577.890137, 'Volume': 0.0, 'CloseUSD': 65.77890137}
# {'Index': 'NYA', 'Date': '2019-10-11', 'Open': 12766.0, 'High': 13025.25, 'Low': 12766.0, 'Close': 12926.91992, 'Adj Close': 12926.91992, 'Volume': 3580460000.0, 'CloseUSD': 12926.91992}
# {'Index': 'NYA', 'Date': '1990-06-25', 'Open': 2036.5, 'High': 2036.5, 'Low': 2036.5, 'Close': 2036.5, 'Adj Close': 2036.5, 'Volume': 0.0, 'CloseUSD': 2036.5}
# {'Index': '000001.SS', 'Date': '2001-08-21', 'Open': 1936.05603, 'High': 1947.402954, 'Low': 1935.77002, 'Close': 1938.870972, 'Adj Close': 1938.870972, 'Volume': 0.0, 'CloseUSD': 310.21935552}
# {'Index': 'IXIC', 'Date': '2002-05-23', 'Open': 1678.420044, 'High': 1697.77002, 'Low': 1651.890015, 'Close': 1697.630005, 'Adj Close': 1697.630005, 'Volume': 1762570000.0, 'CloseUSD': 1697.630005}
# {'Index': 'IXIC', 'Date': '1994-08-09', 'Open': 720.460022, 'High': 722.609985, 'Low': 719.75, 'Close': 722.609985, 'Adj Close': 722.609985, 'Volume': 267250000.0, 'CloseUSD': 722.609985}
# {'Index': 'NYA', 'Date': '1974-01-28', 'Open': 543.380005, 'High': 543.380005, 'Low': 543.380005, 'Close': 543.380005, 'Adj Close': 543.380005, 'Volume': 0.0, 'CloseUSD': 543.380005}
# {'Index': 'NSEI', 'Date': '2012-11-05', 'Open': 5693.049805, 'High': 5709.200195, 'Low': 5679.5, 'Close': 5704.200195, 'Adj Close': 5704.200195, 'Volume': 0.0, 'CloseUSD': 57.04200195000001}
# {'Index': 'HSI', 'Date': '2008-03-13', 'Open': 22925.41992, 'High': 23007.60938, 'Low': 22251.24023, 'Close': 22301.64063, 'Adj Close': 22301.64063, 'Volume': 2546540800.0, 'CloseUSD': 2899.2132819000003}
# {'Index': 'N225', 'Date': '2010-04-22', 'Open': 10988.00977, 'High': 10989.62012, 'Low': 10866.23047, 'Close': 10949.08984, 'Adj Close': 10949.08984, 'Volume': 144100000.0, 'CloseUSD': 109.4908984}
# {'Index': 'NYA', 'Date': '2004-09-27', 'Open': 6531.350098, 'High': 6531.350098, 'Low': 6496.040039, 'Close': 6496.370117, 'Adj Close': 6496.370117, 'Volume': 1263500000.0, 'CloseUSD': 6496.370117}
# {'Index': 'NYA', 'Date': '1991-11-21', 'Open': 2222.699951, 'High': 2222.699951, 'Low': 2222.699951, 'Close': 2222.699951, 'Adj Close': 2222.699951, 'Volume': 0.0, 'CloseUSD': 2222.699951}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for message in consumer:
#       2     print(message.value)
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1358, in KafkaConsumer.__next__(self)
#    1356     self._iterator = self._message_generator_v2()
#    1357 try:
# -> 1358     return next(self._iterator)
#    1359 except StopIteration:
#    1360     self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1329, in KafkaConsumer._message_generator_v2(self)
#    1327 def _message_generator_v2(self):
#    1328     timeout_ms = 1000 * max(0, self._consumer_timeout - time.monotonic())
# -> 1329     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1330     for tp, records in record_map.items():
#    1331         # Generators are stateful, and it is possible that the tp / records
#    1332         # here may become stale during iteration -- i.e., we seek to a
#    1333         # different offset, pause consumption, or lose assignment.
#    1334         for record in records:
#    1335             # is_fetchable(tp) should handle assignment changes and offset
#    1336             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1337             # outer function destroying the existing iterator/generator
#    1338             # via self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:827, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     825 timer = Timer(timeout_ms)
#     826 while not self._closed:
# --> 827     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     828     if records:
#     829         return records
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:865, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     862 if self.config['group_id'] is not None:
#     863     poll_timeout_ms = min(poll_timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 865 records, idle = self._fetcher.fetch_records(
#     866     max_records, update_offsets=update_offsets, timeout_ms=poll_timeout_ms)
#     867 if not records and idle and poll_timeout_ms > 0:
#     868     # Nothing fetchable and nothing in flight (no assignment, all
#     869     # paused, or no resolvable positions). Sleep up to poll_timeout_ms
#     870     # to avoid busy-looping; poll_timeout_ms is already capped by the
#     871     # coordinator's next-action deadline.
#     872     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\fetcher.py:261, in Fetcher.fetch_records(self, max_records, update_offsets, timeout_ms)
#     258     fut.add_both(_wake)
#     260 try:
# --> 261     self._net.run(self._manager.wait_for, wakeup, timeout_ms)
#     262 except Errors.KafkaTimeoutError:
#     263     pass
#
# File ~\anaconda3\Lib\site-packages\kafka\net\selector.py:330, in NetworkSelector.run(self, coro, *args)
#     328     self._pending_waiters[event] = state
#     329 self.call_soon_threadsafe(waiter)
# --> 330 event.wait()
#     331 if state['exception'] is not None:
#     332     raise state['exception']  # pylint: disable=E0702
#
# File ~\anaconda3\Lib\threading.py:670, in Event.wait(self, timeout)
#     668 signaled = self._flag
#     669 if not signaled:
# --> 670     signaled = self._cond.wait(timeout)
#     671 return signaled
#
# File ~\anaconda3\Lib\threading.py:369, in Condition.wait(self, timeout)
#     367 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     368     if timeout is None:
# --> 369         waiter.acquire()
#     370         gotit = True
#     371     else:
#
# KeyboardInterrupt:

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-drummerw/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://kafka-stock-market-drummerw/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1358, in KafkaConsumer.__next__(self)
#    1356     self._iterator = self._message_generator_v2()
#    1357 try:
# -> 1358     return next(self._iterator)
#    1359 except StopIteration:
#    1360     self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1329, in KafkaConsumer._message_generator_v2(self)
#    1327 def _message_generator_v2(self):
#    1328     timeout_ms = 1000 * max(0, self._consumer_timeout - time.monotonic())
# -> 1329     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1330     for tp, records in record_map.items():
#    1331         # Generators are stateful, and it is possible that the tp / records
#    1332         # here may become stale during iteration -- i.e., we seek to a
#    1333         # different offset, pause consumption, or lose assignment.
#    1334         for record in records:
#    1335             # is_fetchable(tp) should handle assignment changes and offset
#    1336             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1337             # outer function destroying the existing iterator/generator
#    1338             # via self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:827, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     825 timer = Timer(timeout_ms)
#     826 while not self._closed:
# --> 827     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     828     if records:
#     829         return records
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:865, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     862 if self.config['group_id'] is not None:
#     863     poll_timeout_ms = min(poll_timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 865 records, idle = self._fetcher.fetch_records(
#     866     max_records, update_offsets=update_offsets, timeout_ms=poll_timeout_ms)
#     867 if not records and idle and poll_timeout_ms > 0:
#     868     # Nothing fetchable and nothing in flight (no assignment, all
#     869     # paused, or no resolvable positions). Sleep up to poll_timeout_ms
#     870     # to avoid busy-looping; poll_timeout_ms is already capped by the
#     871     # coordinator's next-action deadline.
#     872     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\fetcher.py:261, in Fetcher.fetch_records(self, max_records, update_offsets, timeout_ms)
#     258     fut.add_both(_wake)
#     260 try:
# --> 261     self._net.run(self._manager.wait_for, wakeup, timeout_ms)
#     262 except Errors.KafkaTimeoutError:
#     263     pass
#
# File ~\anaconda3\Lib\site-packages\kafka\net\selector.py:330, in NetworkSelector.run(self, coro, *args)
#     328     self._pending_waiters[event] = state
#     329 self.call_soon_threadsafe(waiter)
# --> 330 event.wait()
#     331 if state['exception'] is not None:
#     332     raise state['exception']  # pylint: disable=E0702
#
# File ~\anaconda3\Lib\threading.py:670, in Event.wait(self, timeout)
#     668 signaled = self._flag
#     669 if not signaled:
# --> 670     signaled = self._cond.wait(timeout)
#     671 return signaled
#
# File ~\anaconda3\Lib\threading.py:369, in Condition.wait(self, timeout)
#     367 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     368     if timeout is None:
# --> 369         waiter.acquire()
#     370         gotit = True
#     371     else:
#
# KeyboardInterrupt:
